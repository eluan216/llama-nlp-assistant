# %% [markdown]
# # Exploration Notebook
#
# Use this notebook for rapid experimentation with chunking, embeddings, retrieval, and generation before integrating into the main app.

# %%
import sys
sys.path.append("..")

from src.data_loader import load_document
from src.chunking import chunk_text, get_chunk_stats
from src.embeddings import EmbeddingModel
from src.retriever import VectorStore
from src.llm_pipeline import LLMPipeline

# %% [markdown]
# ## 1. Load a sample document
#
# Place a PDF or TXT file in the `data/` folder and update the path below.

# %%
# text = load_document("../data/your_document.pdf")
# print(text[:1000])

# %% [markdown]
# ## 2. Chunking

# %%
# chunks = chunk_text(text, chunk_size=500, chunk_overlap=50)
# print(get_chunk_stats(chunks))
# print(chunks[0])

# %% [markdown]
# ## 3. Embeddings + Retrieval

# %%
# emb = EmbeddingModel()
# vs = VectorStore(emb)
# vs.build(chunks)
# results = vs.search("your question here", top_k=3)
# for chunk, score in results:
#     print(f"Score: {score:.3f}")
#     print(chunk[:300])
#     print("-" * 40)
